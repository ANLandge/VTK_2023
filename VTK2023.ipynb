# %% [markdown]
# <a href="https://colab.research.google.com/github/ANLandge/VTK_2023/blob/main/VTK2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Classes and inheritance

# %% [markdown]
# 1. Create a class `LivingThing` with attributes - `genus`, `species`.
# 2. Make an instance of the `LivingThing` class with attributes of your choice. Print the attributes of the instance.
# 3. Create child classes of `LivingThing` called `Bacteria`, `Protists`, `Plants`, `Fungi`, and `Animals`. The child classes should inherit all the attributes of the parent class. Add an attribute called `kingdom` to each child class.
# 4. Make at least one instance of each of the child classes.
# Print the attributes of the instance.
# 5. Create a class called `Vehicle` that has attributes `make`, `model`, and `year`. Add a method called `print_info` that prints out the vehicle's make, model, and year.
#
# 6. Create a class called `Car` that inherits from `Vehicle`. Add an attribute called `num_doors` and a method called `print_doors` that prints out the number of doors the car has.
#
# 7. Create a class called `Truck` that also inherits from `Vehicle`. Add an attribute called `bed_size` and a method called `print_bed_size` that prints out the truck's bed size.
#
# 8. Create an instance of the `Car` class and call the `print_info` and `print_doors` methods.
#
# 9. Create an instance of the `Truck` class and call the `print_info` and `print_bed_size` methods.
#
# 10. Create a class called `Rectangle` with attributes `length` and `width`. Add a method called `area` that calculates and returns the area of the rectangle.
#
# 11. Create a class called `Square` that inherits from `Rectangle`. Add a method called `perimeter` that calculates and returns the perimeter of the square.
#
# 12. Create an instance of the `Rectangle` class and call the `area` method.
#
# 13. Create an instance of the `Square` class and call the `area` and `perimeter` methods.

# %%
"""
1. Create a class `LivingThing` with attributes - `genus`, `species`.
2. Make an instance of the `LivingThing` class with attributes of your choice. Print the attributes of the instance.
"""

class LivingThing:
    def __init__(self, genus, species):
        self.genus = genus
        self.species = species

my_living_thing = LivingThing("Homo", "sapiens")
print(my_living_thing.genus)  # Output: Homo
print(my_living_thing.species)  # Output: sapiens
# Out:
# Homo
# sapiens

# %%
"""
Create child classes of LivingThing called Bacteria, Protists, Plants, Fungi, and Animals. 
The child classes should inherit all the attributes of the parent class. 
Add an attribute called kingdom to each child class.

Make at least one instance of each of the child classes. Print the attributes of the instance.

"""

class Bacteria(LivingThing):
    kingdom = "Monera"

class Protists(LivingThing):
    kingdom = "Protista"

class Plants(LivingThing):
    kingdom = "Plantae"

class Fungi(LivingThing):
    kingdom = "Fungi"

class Animals(LivingThing):
    kingdom = "Animalia"

my_bacteria = Bacteria("Escherichia", "coli")
print(my_bacteria.genus)  # Output: Escherichia
print(my_bacteria.species)  # Output: coli
print(my_bacteria.kingdom)  # Output: Monera

my_protist = Protists("Paramecium", "aurelia")
print(my_protist.genus)  # Output: Paramecium
print(my_protist.species)  # Output: aurelia
print(my_protist.kingdom)  # Output: Protista

my_plant = Plants("Arabidopsis", "thaliana")
print(my_plant.genus)  # Output: Arabidopsis
print(my_plant.species)  # Output: thaliana
print(my_plant.kingdom)  # Output: Plantae

my_fungi = Fungi("Saccharomyces", "cerevisiae")
print(my_fungi.genus)  # Output: Saccharomyces
print(my_fungi.species)  # Output: cerevisiae
print(my_fungi.kingdom)  # Output: Fungi

my_animal = Animals("Homo", "sapiens")
print(my_animal.genus)  # Output: Homo
print(my_animal.species)  # Output: sapiens
print(my_animal.kingdom)  # Output: Animalia
# Out:
# Escherichia
# coli
# Monera
# Paramecium
# aurelia
# Protista
# Arabidopsis
# thaliana
# Plantae
# Saccharomyces
# cerevisiae
# Fungi
# Homo
# sapiens
# Animalia

# %%
"""
Create a class called Vehicle that has attributes make, model, and year. 
Add a method called print_info that prints out the vehicle's make, model, and year.

Create a class called Car that inherits from Vehicle. 
Add an attribute called num_doors and a method called print_doors that prints out the number of doors the car has.

Create a class called Truck that also inherits from Vehicle. 
Add an attribute called bed_size and a method called print_bed_size that prints out the truck's bed size.

Create an instance of the Car class and call the print_info and print_doors methods.

Create an instance of the Truck class and call the print_info and print_bed_size methods.

"""

class Vehicle:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

    def print_info(self):
        print(f"{self.year} {self.make} {self.model}")


class Car(Vehicle):
    def __init__(self, make, model, year, num_doors):
        super().__init__(make, model, year)
        self.num_doors = num_doors

    def print_doors(self):
        print(f"This car has {self.num_doors} doors.")

class Truck(Vehicle):
    def __init__(self, make, model, year, bed_size):
        super().__init__(make, model, year)
        self.bed_size = bed_size

    def print_bed_size(self):
        print(f"This truck has a {self.bed_size}-foot bed.")

my_car = Car("Toyota", "Corolla", 2022, 4)
my_car.print_info()  # Output: 2022 Toyota Corolla
my_car.print_doors()  # Output: This car has 4 doors.

my_truck = Truck("Ford", "F-150", 2021, 6)
my_truck.print_info()  # Output: 2021 Ford F-150
my_truck.print_bed_size()  # Output: This truck has a 6-foot bed.
# Out:
# 2022 Toyota Corolla
# This car has 4 doors.
# 2021 Ford F-150
# This truck has a 6-foot bed.

# %%
"""
Create a class called Rectangle with attributes length and width. Add a method called area that calculates and returns the area of the rectangle.

Create a class called Square that inherits from Rectangle. Add a method called perimeter that calculates and returns the perimeter of the square.

Create an instance of the Rectangle class and call the area method.

Create an instance of the Square class and call the area and perimeter methods.

Create a class called Animal with attributes species and name. Add a method called make_sound that prints out the sound the animal makes.

"""

class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

class Square(Rectangle):
    def __init__(self, side):
        super().__init__(side, side)

    def perimeter(self):
        return 4 * self.width


my_rectangle = Rectangle(5, 8)
print(my_rectangle.area())  # Output: 40

my_square = Square(4)
print(my_square.area())  # Output: 16
print(my_square.perimeter())  #
# Out:
# 40
# 16
# 16

# %% [markdown]
# # Python super() and multiple inheritance
#
# ref- https://www.programiz.com/python-programming/methods/built-in/super
#
# "The super() builtin returns a proxy object (temporary object of the superclass) that allows us to access methods of the base class."

# %%
class Animal:
  def __init__(self, Animal):
    print(Animal, 'is an animal.');

class Mammal(Animal):
  def __init__(self, mammalName):
    print(mammalName, 'is a warm-blooded animal.')
    super().__init__(mammalName)
    
class NonWingedMammal(Mammal):
  def __init__(self, NonWingedMammal):
    print(NonWingedMammal, "can't fly.")
    super().__init__(NonWingedMammal)

class NonMarineMammal(Mammal):
  def __init__(self, NonMarineMammal):
    print(NonMarineMammal, "can't swim.")
    super().__init__(NonMarineMammal)

class Dog(NonMarineMammal, NonWingedMammal):
  def __init__(self):
    print('Dog has 4 legs.');
    super().__init__('Dog')
    
d = Dog()
print('')
bat = NonMarineMammal('Bat')
# Out:
# Dog has 4 legs.
# Dog can't swim.
# Dog can't fly.
# Dog is a warm-blooded animal.
# Dog is an animal.
#
# Bat can't swim.
# Bat is a warm-blooded animal.
# Bat is an animal.

# %% [markdown]
# # Matplotlib
# * User guide \
# https://matplotlib.org/stable/users/index.html
#
# * Intro to different plot types \
# https://matplotlib.org/stable/plot_types/index.html
#
# * Cheatsheets \
# https://matplotlib.org/cheatsheets/

# %% [markdown]
# # Matplotlib exercises
#
# 1. Import the necessary libraries and create an empty figure using `plt.figure()`.
# 2. Plot a simple line graph using `plt.plot()`.
# 3. Customize the color, linestyle, and marker of the line graph.
# 4. Add a title and axis labels to the plot.
# 5. Create a scatter plot using `plt.scatter()`.
# 6. Customize the color, size, and alpha of the markers in the scatter plot.
# 7. Add a legend to the plot.
# 8. Create a bar chart using `plt.bar()`.
# 9. Customize the color and width of the bars in the bar chart.
# 10. Create a histogram using `plt.hist()`.
# 11. Customize the color, number of bins, and range of values in the histogram.
# 12. Create a pie chart using `plt.pie()`.
# 13. Customize the color and slice sizes of the pie chart.
# 14. Add labels to the slices of the pie chart.
# 15. Create a stacked bar chart using `plt.bar()` and multiple datasets.
# 16. Create a stacked area chart using `plt.fill_between()` and multiple datasets.
# 17. Create a box plot using `plt.boxplot()`.
# 18. Customize the color and style of the boxes, whiskers, and outliers in the box plot.
# 19. Create a violin plot using `plt.violinplot()`.
# 20. Customize the color and style of the violins and the width of the bandwidth in the violin plot.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Exercise 1 - Import the necessary libraries and create an empty figure using plt.figure().
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]
plt.plot(x, y)
plt.show()

# %%
# Exercise 2 - Plot a simple line graph using plt.plot().
x = np.linspace(-10, 10, 100)
y = x ** 2
plt.plot(x, y)
plt.show()

# %%
# Exercise 3 - Customize the color, linestyle, and marker of the line graph.

x = np.linspace(-2 * np.pi, 2 * np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x, y1)
plt.plot(x, y2)
plt.legend(['sin', 'cos'])
plt.show()

# %%
# Exercise 4 -Add a title and axis labels to the plot.
x = [1, 2, 3, 4]
y1 = [1, 4, 9, 16]
y2 = [2, 4, 6, 8]
plt.plot(x, y1, 'r--', label='Squares')
plt.plot(x, y2, 'g^', label='Doubles')
plt.legend()
plt.show()

# %%
# Exercise 5 - Create a scatter plot using plt.scatter().

x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
plt.plot(x, y, 'r--')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Sine Wave')
plt.show()

# %%
# Exercise 6 - Customize the color, size, and alpha of the markers in the scatter plot.

x = np.random.normal(0, 1, 1000)
plt.hist(x, bins=30)
plt.show()

# %%
# Exercise 7 - Add a legend to the plot.

x = np.random.normal(0, 1, 1000)
y = np.random.normal(0, 1, 1000)
plt.scatter(x, y)
plt.show()

# %%
# Exercise 8 - Create a bar chart using plt.bar().

labels = ['Apples', 'Oranges', 'Bananas']
sizes = [50, 25, 25]
colors = ['red', 'orange', 'yellow']
plt.pie(sizes, labels=labels, colors=colors)
plt.show()

# %%
# Exercise 9 - Customize the color and width of the bars in the bar chart.

x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
plt.plot(x, y, 'r--')
plt.xlim([0, 2 * np.pi])
plt.ylim([-1, 1])
plt.show()

# %%
# Exercise 10 - Create a histogram using plt.hist().

x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
plt.plot(x, y, 'r--')
plt.grid()
plt.show()

# %%
# Exercise 11 - Customize the color, number of bins, and range of values in the histogram.
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
fig, ax = plt.subplots()
ax.plot(x, y, 'r--')
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_title('Sine Wave')
plt.show()

# %%
# Exercise 12

import matplotlib.pyplot as plt

# data for the pie chart
sizes = [20, 30, 50]
labels = ['Apples', 'Oranges', 'Bananas']

# custom colors for the slices
colors = ['#ff9999','#66b3ff','#99ff99']

# create the pie chart
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)

# add a title to the pie chart
plt.title('Fruit Distribution')

# display the chart
plt.show()

# %%
# Exercise 13

import matplotlib.pyplot as plt

# data for the pie chart
sizes = [20, 30, 50]
labels = ['Apples', 'Oranges', 'Bananas']

# custom colors for the slices
colors = ['#ff9999','#66b3ff','#99ff99']

# custom sizes for the slices
explode = (0, 0.1, 0)

# create the pie chart
plt.pie(sizes, labels=labels, colors=colors, explode=explode, autopct='%1.1f%%', startangle=90)

# add a title to the pie chart
plt.title('Fruit Distribution')

# display the chart
plt.show()

# %%
# Exercise 14 - Add labels to the slices of the pie chart:
import matplotlib.pyplot as plt

# data for the pie chart
sizes = [20, 30, 50]
labels = ['Apples', 'Oranges', 'Bananas']

# custom colors for the slices
colors = ['#ff9999','#66b3ff','#99ff99']

# custom sizes for the slices
explode = (0, 0.1, 0)

# create the pie chart
plt.pie(sizes, labels=labels, colors=colors, explode=explode, autopct='%1.1f%%', startangle=90)

# add a title to the pie chart
plt.title('Fruit Distribution')

# add labels to the slices of the pie chart
for i, label in enumerate(labels):
    plt.annotate(label, (0, 0), xytext=(1.5, -1.2+i*0.2), fontsize=12, fontweight='bold', textcoords='offset points')

# display the chart
plt.show()

# %%
# Exercise 15 - Create a stacked bar chart using plt.bar() and multiple datasets:
import matplotlib.pyplot as plt
import numpy as np

# data for the stacked bar chart
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
labels = ['Group1', 'Group2', 'Group3', 'Group4', 'Group5']

# create the bars for the men and women
fig, ax = plt.subplots()
ax.bar(labels, men_means, label='Men')
ax.bar(labels, women_means, bottom=men_means, label='Women')

# add a title and axis labels
plt.title('Stacked Bar Chart')
plt.xlabel('Groups')
plt.ylabel('Scores')

# add a legend to the chart
plt.legend()

# display the chart
plt.show()

# %%
# Exercise 16 
"""
Stacked Area Chart using plt.fill_between()

A stacked area chart is used to show the composition of a whole by 
showing how different parts of a data contribute to the whole over time. 
It is similar to a stacked bar chart, but is used when the data is continuous.

In this exercise, we will use the fill_between function of pyplot module in 
Matplotlib to create a stacked area chart using multiple datasets.
"""

import matplotlib.pyplot as plt
import numpy as np

# Create the data
x = np.array([1, 2, 3, 4, 5])
y1 = np.array([1, 2, 3, 4, 5])
y2 = np.array([3, 4, 2, 5, 1])
y3 = np.array([2, 5, 1, 4, 3])

# Create a figure and axis
fig, ax = plt.subplots()

# Stack the data and plot it as filled areas
ax.fill_between(x, y1, color='blue', alpha=0.5)
ax.fill_between(x, y1, y1+y2, color='green', alpha=0.5)
ax.fill_between(x, y1+y2, y1+y2+y3, color='red', alpha=0.5)

# Add labels and title
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('Stacked Area Chart')

# Show the plot
plt.show()

# %% [markdown]
# * Exercise 17 -
# Box Plot using plt.boxplot()
#
# A box plot is used to show the distribution of a dataset by displaying the range and distribution of the data. It is used to display the minimum, maximum, median, and quartiles of a dataset. It is useful for identifying outliers and comparing distributions.
#
# In this exercise, we will use the boxplot function of pyplot module in Matplotlib to create a box plot and customize the color and style of the boxes, whiskers, and outliers.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create the data
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# Create a figure and axis
fig, ax = plt.subplots()

# Create the box plot and customize the colors and style
bp = ax.boxplot(data, patch_artist=True, notch=True,
                capprops=dict(color='black', linewidth=2),
                whiskerprops=dict(color='black', linewidth=2),
                flierprops=dict(marker='o', markerfacecolor='red', markersize=5),
                boxprops=dict(facecolor='green', color='black', linewidth=2),
                medianprops=dict(color='black', linewidth=2))

# Add labels and title
ax.set_xticklabels(['Data 1', 'Data 2', 'Data 3'])
ax.set_xlabel('Data')
ax.set_ylabel('Value')
ax.set_title('Box Plot')

# Show the plot
plt.show()

# %% [markdown]
# 18. Customize the color and style of the boxes, whiskers, and outliers in the box plot.

# %%
import matplotlib.pyplot as plt
import numpy as np

# create some data for the box plot
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# set the color and style of the boxes, whiskers, and outliers
boxprops = dict(linestyle='--', linewidth=2, color='darkgreen')
whiskerprops = dict(linestyle='-.', linewidth=1.5, color='orange')
capprops = dict(linestyle=':', linewidth=2, color='red')
flierprops = dict(marker='o', markerfacecolor='blue', markersize=8, linestyle='none')

# create the box plot and pass the color and style parameters
fig, ax = plt.subplots()
ax.boxplot(data, boxprops=boxprops, whiskerprops=whiskerprops, capprops=capprops, flierprops=flierprops)

# set the x-axis label and the y-axis label
ax.set_xlabel('Data')
ax.set_ylabel('Value')

# set the title of the plot
ax.set_title('Customized Box Plot')

# display the plot
plt.show()

# %% [markdown]
# 19. Create a violin plot using `plt.violinplot()`.

# %% [markdown]
# A violin plot is similar to a box plot, but it also shows the probability density of the data at different values. We can create a violin plot using the violinplot() function from Matplotlib.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create some sample data
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# Create a violin plot
plt.violinplot(data)

# Set the x-axis label
plt.xlabel('Sample')

# Set the y-axis label
plt.ylabel('Value')

# Set the title of the plot
plt.title('Violin Plot')

# Show the plot
plt.show()

# %% [markdown]
# In this code, we first import Matplotlib and Numpy. We then create some sample data using Numpy's random.normal() function. We create three datasets, each with a different standard deviation. We then pass these datasets to the violinplot() function to create the violin plot. We set the x-axis label to "Sample", the y-axis label to "Value", and the title to "Violin Plot". Finally, we show the plot using the show() function.

# %% [markdown]
# * Exercise 20.
# Customize the color and style of the violins and the width of the bandwidth in the violin plot.

# %% [markdown]
# We can customize the color and style of the violins and the width of the bandwidth in the violin plot using the violinparts attribute of the returned dictionary from violinplot().

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create some sample data
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# Create a violin plot
vp = plt.violinplot(data, showmedians=True, widths=0.7)

# Customize the color and style of the violins
for pc in vp['bodies']:
    pc.set_facecolor('red')
    pc.set_edgecolor('black')
    pc.set_alpha(0.5)

# Customize the color and style of the medians
for median in vp['cmedians']:
    median.set_color('blue')
    median.set_linestyle('--')

# Customize the bandwidth
plt.xticks([1, 2, 3], ['Sample 1', 'Sample 2', 'Sample 3'])
plt.yticks(np.arange(-5, 6, 1))
plt.xlim(0.5, 3.5)
plt.ylim(-5, 5)
plt.title('Customized Violin Plot')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-e502c57e07c4> in <cell line: 17>()
#      15
#      16 # Customize the color and style of the medians
# ---> 17 for median in vp['cmedians']:
#      18     median.set_color('blue')
#      19     median.set_linestyle('--')
#
# TypeError: 'LineCollection' object is not iterable

# %% [markdown]
# In this code, we first import Matplotlib and Numpy. We then create some sample data using Numpy's random.normal() function. We create three datasets, each with a different standard deviation. We pass these datasets to the violinplot() function to create the violin plot. We set the showmedians argument to True to show the median values. We also set the widths argument to 0.7 to make the violins narrower.
#
# We then customize the color and style of the violins and medians. We loop through the bodies and cmedians attributes of the returned dictionary from violinplot() and set their colors and styles using the set_facecolor(), set_edgecolor(), set_alpha(), set_color(), and set_linestyle() functions.
#
# Finally, we customize the bandwidth using various Matplotlib functions

# %% [markdown]
# I apologize for the mistake. Here's the corrected code:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create sample data
data1 = np.random.normal(loc=0, scale=1, size=100)
data2 = np.random.normal(loc=2, scale=1, size=100)
data3 = np.random.normal(loc=3, scale=2, size=100)
data4 = np.random.normal(loc=-1, scale=2, size=100)
data = [data1, data2, data3, data4]

# Create violin plot
vp = plt.violinplot(data)

# Customize the color and style of the violins
for body in vp['bodies']:
    body.set_color('red')
    body.set_edgecolor('black')
    body.set_alpha(0.5)

# Customize the width of the bandwidth
for b in vp['bodies']:
    b.set_facecolor('red')
    b.set_alpha(0.25)

# Customize the color and style of the medians
for median in vp['cbars']:
    median.set_color('blue')
    median.set_linestyle('--')
    median.set_linewidth(2)

# Set x-axis label
plt.xlabel('Data')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-1d1e8b9257dd> in <cell line: 26>()
#      24
#      25 # Customize the color and style of the medians
# ---> 26 for median in vp['cbars']:
#      27     median.set_color('blue')
#      28     median.set_linestyle('--')
#
# TypeError: 'LineCollection' object is not iterable

# %% [markdown]
# # Pandas
#
# * User guide \
# https://pandas.pydata.org/docs/user_guide/index.html#user-guide

# %% [markdown]
# # Pandas exercises

# %% [markdown]
# Beginner level exercises for a user of the Pandas library in Python:
#
# 1. Create a Pandas DataFrame from a dictionary and print it.
# 2. Load a CSV file into a Pandas DataFrame and print its first 5 rows.
# 3. Filter a Pandas DataFrame to only include rows where a certain column meets a condition.
# 4. Group a Pandas DataFrame by a certain column and calculate the mean of another column.
# 5. Rename the columns of a Pandas DataFrame.
# 6. Merge two Pandas DataFrames together on a common column.
# 7. Replace all occurrences of a certain value in a Pandas DataFrame with another value.
# 8. Calculate the correlation matrix between columns in a Pandas DataFrame.
# 9. Pivot a Pandas DataFrame to create a new table from the original data.
# 10. Export a Pandas DataFrame to a CSV file.

# %%
import pandas as pd

# 1. Create a Pandas DataFrame from a dictionary and print it.

# Create dictionary
data = {'name': ['Alice', 'Bob', 'Charlie'],
        'age': [25, 30, 35],
        'country': ['USA', 'Canada', 'Mexico']}

# Create DataFrame
df = pd.DataFrame(data)

# Print DataFrame
print(df)
# Out:
#       name  age country
# 0    Alice   25     USA
# 1      Bob   30  Canada
# 2  Charlie   35  Mexico

# %%
# 2. Load a CSV file into a Pandas DataFrame and print its first 5 rows.


# Load CSV file into DataFrame
df = pd.read_csv('data.csv')

# Print first 5 rows of DataFrame
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-18be645c17be> in <cell line: 5>()
#       3
#       4 # Load CSV file into DataFrame
# ----> 5 df = pd.read_csv('data.csv')
#       6
#       7 # Print first 5 rows of DataFrame
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
# 3. Filter a Pandas DataFrame to only include rows where a certain column meets a condition.


# Load CSV file into DataFrame
df = pd.read_csv('data.csv')

# Filter rows where sales are greater than 12000
df_filtered = df[df['sales'] > 12000]

# Print filtered DataFrame
print(df_filtered)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sales'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#4. Group a Pandas DataFrame by a certain column and calculate the mean of another column.


# Create a sample dataframe
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Emily'],
    'Age': [25, 30, 35, 40, 45],
    'Salary': [50000, 60000, 70000, 80000, 90000]
}

df = pd.DataFrame(data)

# Group the dataframe by the 'Age' column and calculate the mean of the 'Salary' column
grouped_df = df.groupby('Age')['Salary'].mean()

print(grouped_df)
# Out:
# Age
# 25    50000.0
# 30    60000.0
# 35    70000.0
# 40    80000.0
# 45    90000.0
# Name: Salary, dtype: float64

# %%
# 5. Rename the columns of a Pandas DataFrame.


# Create a sample dataframe
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Emily'],
    'Age': [25, 30, 35, 40, 45],
    'Salary': [50000, 60000, 70000, 80000, 90000]
}

df = pd.DataFrame(data)

# Rename the columns of the dataframe
df = df.rename(columns={'Name': 'Employee Name', 'Age': 'Employee Age', 'Salary': 'Employee Salary'})

print(df)
# Out:
#   Employee Name  Employee Age  Employee Salary
# 0         Alice            25            50000
# 1           Bob            30            60000
# 2       Charlie            35            70000
# 3         David            40            80000
# 4         Emily            45            90000

# %%
# 6. Merge two Pandas DataFrames together on a common column.


# Create two sample dataframes
data1 = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Emily'],
    'Age': [25, 30, 35, 40, 45]
}

data2 = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Emily'],
    'Salary': [50000, 60000, 70000, 80000, 90000]
}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# Merge the two dataframes on the 'Name' column
merged_df = pd.merge(df1, df2, on='Name')

print(merged_df)
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000
# 3    David   40   80000
# 4    Emily   45   90000

# %%
# 7. Replace all occurrences of a certain value in a Pandas DataFrame with another value.


# create a sample dataframe
df = pd.DataFrame({'A': [1, 2, 3, 4], 'B': [5, 6, 7, 8], 'C': [9, 10, 11, 12]})

# replace all occurrences of 7 with 13
df = df.replace(7, 13)

print(df)
# Out:
#    A   B   C
# 0  1   5   9
# 1  2   6  10
# 2  3  13  11
# 3  4   8  12

# %%
# 8. Calculate the correlation matrix between columns in a Pandas DataFrame.


# create a sample dataframe
df = pd.DataFrame({'A': [1, 2, 3, 4], 'B': [5, 6, 7, 8], 'C': [9, 10, 11, 12]})

# calculate the correlation matrix
corr_matrix = df.corr()

print(corr_matrix)

# %%
# 9. Pivot a Pandas DataFrame to create a new table from the original data.

# create a sample dataframe
df = pd.DataFrame({'A': [1, 2, 3, 4], 'B': [5, 6, 7, 8], 'C': [9, 10, 11, 12]})

# calculate the correlation matrix
corr_matrix = df.corr()

print(corr_matrix)

# %%
# create a sample dataframe
df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                   'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                   'C': [1, 2, 3, 4, 5, 6, 7, 8],
                   'D': [9, 10, 11, 12, 13, 14, 15, 16]})

# pivot the dataframe
df_pivot = df.pivot_table(values='C', index='A', columns='B')

print(df_pivot)

# %%
# 10. Export a Pandas DataFrame to a CSV file

# create a sample dataframe
df = pd.DataFrame({'A': [1, 2, 3, 4], 'B': [5, 6, 7, 8], 'C': [9, 10, 11, 12]})

# export the dataframe to a csv file
df.to_csv('data.csv', index=False)

# read the csv file back into a dataframe
df_csv = pd.read_csv('data.csv')

print(df_csv)
# Out:
#    A  B   C
# 0  1  5   9
# 1  2  6  10
# 2  3  7  11
# 3  4  8  12

# %%
import os

cwdPath= os.getcwd()

print(cwdPath)

os.mkdir(cwdPath+"/testDir")

os.chdir('/content/testDir')
cwdPath= os.getcwd()
print(cwdPath)
# Out:
# /content
# /content/testDir

# %% [markdown]
# # Agent-basesd modeling

# %% [markdown]
# **Agent Based Modeling in Python**
#
# Steps
# 1. Think about your system. Figure out your agents. Catagorise them. List their properties. List their interactions.
# 2. Write down the equations that dscribe your system with the parameters and the assumptions.
# 3. Clearly define the aim of mathematical modeling. What would be your inputs? What will be the output? How will you visualize/analyze the results.
# 4. Write down the structure of your code. How many classes do you need? What methods should these classes have?
# 5. Write the code. Test the code. Debug. Repeat.

# %% [markdown]
# **System desciption:**
#
# The system consists of organisms. Some are prey and others are predators. Both types can reproduce, and die. Preadtors eat the prey and then the prey is dead. Predators reproduce when there is sufficient prey and other predators are present neayby for mating. They preys reproduce at a constant rate.
#
#  The prey-predator system can be described by the classical lotka-volterra system of equations -
# (Ref. - Shim, H. & Fishwick, P. A. doi:10.1016/B978-008045405-4.00225-1.)
#
#  Predator = Fox = F
#
#  Prey = Rabbit = R
#
#  The **assumptions** are
#  1. Rabbits reproduce at a rate dependent on current rabbit population (exponential growth).
#  2. Foxes die at a rate dependent on current fox population (exponential decay/death).
#  3. Rabbits are eaten by foxes at rate dependent on both rabbit and fox populations.
#  4. Foxes reproduce at rate dependent on both rabbit and fox populations.
#
#  The **parameters** are -
# * a - rabbit birth rate constant
# * b - rabbit death rate constant
# * c - fox birth rate constant
# * d - fox death rate constant
#
#
#  This gives us the **equations**-
#
# * *dR/dt = a X R - b X F X R*
#
# * *dF/dt = c X F X R - d X F*
#
# Aims:
# 1. To simulate the spatiotemporal dynamics of the system
#
# 2. To visualize the pre-predator interactions and population change over time
#
# 3. To Test model behaviour at different parameters, initial conditions, etc.
#
# 4. To have some fun

# %%
"""
This program provides classes and methods to simulate a simple agent-based
predator-prey model.

"""
# import the necessary packages

import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from datetime import datetime
import time
import os
from IPython import display

# %matplotlib inline 
# use matplotlib inline mode to disply plots

class organism:
    """
    A general class that contains all the agents.
    """
    def __init__(self, id, typ, sz, rng):
        self.typ= typ # 'prey' or 'predator'
        self.id=str(id).zfill(4)  # each agent gets an id
        self.name=typ+self.id # and a name
        a=np.random.randint(0,sz) # a random x-coordinate
        b=np.random.randint(0,sz) # a random y-coordinate
        self.pos=np.array([a,b]) # initial position of the agent
        self.rng = rng # the range of the agent


class simulateModel:
    """
    This class contains methods to update the system state
    """
    def __init__(self, steps, outdir, landSize, initial_prey, initial_predator, rngPre, rngPrd, a, b, c, d):
        self.steps=steps 
        self.sz = landSize # the size of the landscape where the organisms live
        self.outdir= outdir
        self.preyCnt = initial_prey
        self.prdCnt = initial_predator
        self.rngPre = rngPre 
        self.rngPrd= rngPrd
        self.a = a # prey birth rate
        self.b = b # prey death rate
        self.c = c # predator birth rate
        self.d = d # predator death rate
        self.cntDict={} # a dictionary to store prey and predator counts
        self.cntDict['prey']= [self.preyCnt]
        self.cntDict['predator']= [self.prdCnt]

    def initialize(self, ):
        """
        This function initializes the model with given number of preys and predators and adds them to a list. 
        """
        self.orgList=[]
        for i in range(self.preyCnt):
            ag= organism(i,'prey', self.sz, self.rngPre)
            self.orgList.append(ag)

        for i in range(self.prdCnt):
            ag = organism(i, 'predator', self.sz, self.rngPrd)
            self.orgList.append(ag)

    
    def moveAgent(self, ag):
        x = (ag.pos[0]+ np.random.randint(-ag.rng,ag.rng)) % self.sz
        y = (ag.pos[1]+ np.random.randint(-ag.rng,ag.rng)) % self.sz
        newPos= np.array([x,y])

        ag.pos = newPos
        pass
    
    def getNeighbours(self,ag):
        """
        This function checks who is in the vicinity of the given agent. 
        output:
        [1,1] if prey and predator is nearby
        [1,0] only prey is near
        [0,1] only predator is near
        [0,0] nobody is closeby
        """
        self.neighbours = [0,0]

        for agN in self.orgList:
            if agN.name != ag.name: # to look only for agents other than the given agent
                x1,y1 = ag.pos
                x2,y2 = agN.pos
                dist = np.sqrt((x2-x1)**2 + (y2-y1)**2) # compute euclidean distance
                if dist<=ag.rng:
                    if agN.typ=='prey':
                        self.neighbours[0] = 1
                    elif agN.typ=='predator':
                        self.neighbours[1] = 1
            if self.neighbours==[1,1]:
                break

    def update(self,step):
        """
        The logic - at each step
        1. the prey reproduces with probability 'a' 
        2. the prey dies with probability 'b' (if a predator is nearby)
        3. the predator reproduce with probability 'c' (if a prey is nearby)
        4. the predator dies at probability 'd' 

        """
        for ag in self.orgList:
            self.moveAgent(ag)
            self.getNeighbours(ag) # first see who is nearby

            if ag.typ=='prey':  # the logic for prey
                # if self.neighbours[0]==1:
                self.doIt = np.random.choice([0,1], p=[1-self.a, self.a]) # applying the probability
                if self.doIt:
                    # add new prey
                    agN = organism(self.preyCnt,'prey', self.sz, self.rngPre)
                    agN.pos= ag.pos
                    self.orgList.append(agN) 
                    self.preyCnt+=1 

                if self.neighbours[1]==1:
                    self.doIt = np.random.choice([0,1], p=[1-self.b, self.b])
                    if self.doIt:
                        # the prey gets eaten 
                        self.orgList.remove(ag) 
                        del ag
                        self.preyCnt-=1 

            elif ag.typ=='predator':
                if self.neighbours[0]==1:
                    self.doIt = np.random.choice([0,1], p=[1-self.c, self.c])
                    if self.doIt:
                        # the predator reproduces
                        agN = organism(self.prdCnt,'predator', self.sz, self.rngPrd)
                        agN.pos= ag.pos
                        self.orgList.append(agN) 
                        self.prdCnt+=1 

                if self.neighbours==[0,1]:
                    self.doIt = np.random.choice([0,1], p=[1-self.d, self.d])
                    if self.doIt:
                        # the predator dies
                        self.orgList.remove(ag) # remove organism from the list
                        del ag
                        self.prdCnt-=1 #decrease prdCnt by 1

        #update prey and predator counts
        self.cntDict['prey'].append(self.preyCnt)
        self.cntDict['predator'].append(self.prdCnt)

    def plotAgents(self, step):
        """
        This function makes the plots of prey and predator distribution and counts.
        """
        plt.clf()
        display.clear_output(wait=True)

        plt.subplot(1,2,1) # to show the distribution
        plt.title(f"step_{step}")
        plt.xticks([])
        plt.yticks([])
        plt.xlim(0,self.sz)
        plt.ylim(0,self.sz)
        
        for ag in self.orgList:
            if ag.typ=="prey":
                plt.plot(ag.pos[0], ag.pos[1], 'o', color='k')
            elif ag.typ=="predator":
                plt.plot(ag.pos[0], ag.pos[1], 'x', color='b')
            else:
                None
      
        plt.subplot(1,2,2) # to show the counts
        plt.xlabel("Step number")
        plt.ylabel("Counts")

        xAx = np.linspace(0,step+1,step+2)
        plt.plot(xAx, self.cntDict['prey'], '-', color='k', label='prey')
        plt.plot(xAx, self.cntDict['predator'], '-', color='b', label='predator')    
        plt.legend()
        
        display.display(plt.gcf())        
        stepID = f"{step}".zfill(4)
        outName = self.outdir/f"agentsAt_{stepID}.tif"
        plt.savefig(outName)

# %%
print("\n**************************************************** \nStarting the simulation program...")
t1 = time.time()

#make directory to store the results
cwdPath=Path(os.path.abspath(os.getcwd()))

#get the current date and time to create a unique directory for each simulation
now=datetime.now()
datetime_str=(now.strftime("%Y%m%d_%H%M%S_"))

dirName=str(datetime_str+"prey_predator")
outdir=cwdPath/'data'/dirName
outdir.mkdir(mode=0o777, parents=True, exist_ok=True)

print("Created directory for results ...")

# define parameters
alpha=0.1
beta=0.4
delta=0.2
gamma=0.8

steps = 200
landSize = 800
initial_prey= 40
initial_predator = 40
rngPre = 20
rngPrd = 40

# populate the land with some organisms
print("Running simulation ...")
sim1 = simulateModel(steps, outdir, landSize, initial_prey, initial_predator, rngPre, rngPrd,
  alpha, beta, delta, gamma)

sim1.initialize()

# update the population
plt.figure(figsize= [11, 5])

for step in range(steps):
    sim1.update(step)
    sim1.plotAgents(step)

    if sim1.preyCnt==0:
        print("All preys died.")
        break

    if sim1.prdCnt==0:
        print("All predators died.")
        break

    if sim1.preyCnt>2000:
        print(f"Maximum prey capacity reached. prey count = {sim1.preyCnt}")
        break

    if sim1.prdCnt>2000:
        print(f"Maximum predator capacity reached. predator count = {sim1.prdCnt}")
        break
plt.close()

t2= time.time()
totalSec= t2-t1
Sec=int(totalSec%60)
Hrs=int(totalSec//3600)
Min=int((totalSec%3600)//60)

print ("Program completed in %sHr:%sMin:%ssec\n"%(Hrs,Min,Sec))
# Out:
# Program completed in 0Hr:3Min:58sec
